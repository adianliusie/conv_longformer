# %%
#for utt sep

#0   (0.823, 0.720) (0.843, 0.731) (0.809, 0.745)
#1   (0.694, 0.775) (0.693, 0.778) (0.689, 0.780)
#2   (0.603, 0.794) (0.619, 0.795) (0.658, 0.778)
#3   (0.637, 0.788) (0.610, 0.790) (0.624, 0.798)
#5   (0.615, 0.799) (0.602, 0.796) (0.617, 0.789)
#8   (0.629, 0.794) (0.603, 0.797) (0.622, 0.798)
#10  (0.624, 0.792) (0.609, 0.799) (0.604, 0.803)
#20  (0.628, 0.796) (0.610, 0.790) 
#30  (0.61,  0.803)  
#50  (0.629, 0.793) (0.617, 0.798) (0.603, 0.798)
#80  (0.666, 0.788) (0.612, 0.801)
#100 (0.594, 0.799) (0.631, 0.789) ()
#150 (0.646, 0.780)
#max (0.589, 0.807)

# %%
#for cls wrap

#0   (0.831, 0.737) (0.864, 0.723) (0.85,  0.731)
#1   (0.672, 0.780) (0.676, 0.778) (0.681, 0.777)
#2   (0.655, 0.792) (0.621, 0.791) (0.616, 0.791)
#3   (0.601, 0.796) (0.630, 0.796) (0.601, 0.801)
#5   (0.618, 0.799) (0.622, 0.786) (0.570, 0.805)
#8   (0.613, 0.797) (0.571, 0.810) (0.587, 0.805)
#10  (0.599, 0.795) (0.646, 0.789) (0.594, 0.796)
#20  (0.590, 0.800) (0.605, 0.801) 
#30  (0.622, 0.792) 
#50  (0.641, 0.798)
#80  (0.661, 0.792)
#100 (0.667, 0.786)
#150 (0.931, 0.715)
#200 (1.050, 0.691)
#max (1.394, 0.588)

# %%
print((0.795+0.789+0.796)/3)
# Out:
# 0.7933333333333333

# %%
#for utt sep

window   = [    0,     1,     2,     3,     5,     8,    10] + [   20,    30,    50,    80,   100,   150, 200  , 300]
utt_sep  = [0.732, 0.777, 0.789, 0.792, 0.794, 0.796, 0.798] + [0.793, 0.803, 0.796, 0.795, 0.794, 0.780, 0.8  , 0.807]
cls_wrap = [0.731, 0.778, 0.791, 0.798, 0.797, 0.804, 0.793] + [0.800, 0.792, 0.798, 0.792, 0.786, 0.715, 0.691, 0.588]

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

window_len = 2*np.array(window)+1

#setting plot to log scale
f, ax = plt.subplots(figsize=(12, 5))
ax.set(xscale="log")
ax.set_xlim(0.9,701)

plt.plot(window_len, utt_sep, marker='o', color='b')
plt.plot(window_len, cls_wrap, marker='o', color='r')

#setting fake xtickmarks
window_temp = window.copy()
window_temp[-1] = 'full ctx'
plt.xticks(window_len, window_temp)
plt.legend(['utt sep', 'cls wrap'])
